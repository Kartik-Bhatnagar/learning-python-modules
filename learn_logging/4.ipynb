# %%
import logging

# %%
logging.basicConfig(level=logging.INFO,format="{levelname} :: {name} :::-> {message}",style="{")

# %%
logging.info("We have used the bracket { style format above")
# Out:
# INFO :: root :::-> We have used the bracket { style format above

# %% [markdown]
# Besides the message text and the log level, it usually makes sense to also have a timestamp in the log record.
