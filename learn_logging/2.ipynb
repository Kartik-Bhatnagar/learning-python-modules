# %%
import logging

# %%
logging.basicConfig(level=logging.INFO)

# %%
logging.debug("This is a debug log, it will not be printed")

# %%
logging.info("This is a info log and now after changing the basic config it will be changed")
# Out:
# INFO:root:This is a info log and now after changing the basic config it will be changed
